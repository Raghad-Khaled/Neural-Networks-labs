# %% [markdown]
# # Bayesian Classifier
# In this lab, you will implement and assess the performance of the Bayesian Classifier.
#
# ## Lab Instructions:
# 1. Read the explanation above each requirement very well
# 2. Read the requirement very well before jumping into the code.
# 3. Some requirements have essay questions in them, make sure you do NOT miss them.
# 4. PLEASE Read the hints! They are clear and made to help you complete the requirement as fast as you should

# %%
#### always keep all your imports in the first cell ####
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import csv
import math

# %matplotlib qt

# %% [markdown]
# ## Requirement
#
# In this requirement, you will build the Bayesian Classifier and test its performance.
#
# You are provided with a data file **data1.csv** containing list of points and their corresponding classes. The format of the data files is shown in the table below.
#
# | |Class|Feature 1|Feature 1|
# |-|-|-|-|
# |Point#1|1|0.271633|-2.93224|
# |Point#2|1|7.020786|-1.98966|
# |Point#3|1|2.901827|-0.91291|
#
#
# You are also provided with a test data file **test_data.csv**. The file contains test points that are unlabelled (i.e. the class to which they belong is unknown).

# %%
# TODO [1] : Read the file 'data1.csv' into the variable data.
# data contains the training data together with labelled classes.
def read_data(file_name):
    ## HINT 1: How is the data ordered in the file?
    rows = []
    with open(file_name, 'r') as file:
        csvreader = csv.reader(file, delimiter=',')
        for row in csvreader:
            rows.append(row)
    ## HINT 2: Do you need to cast the data you read from the file?
    data = np.array(rows).astype(float)
    return data

read_data('data1.csv')
# Out:
# array([[ 3.        ,  3.27208926,  0.72677351],
#        [ 1.        , -6.93777713, -6.44982832],
#        [ 3.        ,  6.05602895,  0.48719482],
#        ...,
#        [ 1.        , -3.28686863, -5.7977003 ],
#        [ 2.        , -1.15237768, 12.15641751],
#        [ 2.        , -1.25571473,  6.49572251]])

# %%
def read_test_data():
    
    # TODO [2.A]: Read the file 'test_data.csv' into the variable test_data
    # test_data contains the unlabelled test class.
    ## HINT: Do you need to cast the data you read from the file?

    test_data = read_data('test_data.csv')
    
    # TODO [2.B]: Read the file 'test_data_true.csv' into the variable test_data_true
    # test_data_true contains the actual classes of the test instances, which you will compare
    # against your predicted classes.
    ## HINT: Do you need to cast the data you read from the file?

    test_data_true = read_data('test_data_true.csv')
    return test_data, test_data_true

#read_test_data()

# %% [markdown]
# ### Machine Learning Terminlology
# Machine learning problems use common termonology (names and notiations) to refer to certain things. It is useful to use this termonology throughout your code to make it readable.
#
# | | |
# |:-|:--- |
# |$M$:|A scalar; represents the number of training points in the training set.|
# |$K$:|A scalar; represents the number of test points in the test set.|
# |$N$:|A scalar; represents the number of features of training set/test set (dimensionality of data).|
# |$X$:|A numpy array of shape $(M \times N)$ containing the training data **without** its labels, where $M$ is the number of training points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset.|
# |$X_{test}$:| A numpy array of shape $(K \times N)$ containing the test data, where $K$ is the number of test points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X_{test}$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset. <br/> The number of columns in $X_{test}$ is equal to the number of columns in $X$ (because they have the same number of features). However, the number of rows in $X_{test}$ is different to the number of rows in $X$.|
# |**$Y$:| A numpy array of shape $(M \times 1)$ containing the labels of the training data. Each row in $Y$ corresponds to the label of the training point in $X$.<br/> For example, $Y[j]$ corresponds to the label of the training point $X[j]$ where $0<=j<M$.|

# %%
# TODO [3]: Fill the values of M, K, N, X, XTest, and Y respectively.
# Do not fill them manually (i.e. do not set N = 3). They should be generic for any input file.  
training_data = read_data('data1.csv')
test_data, test_data_true = read_test_data()

#print(np.shape(training_data)[0])

numClasses = 3 
M = np.shape(training_data)[0]
K = np.shape(test_data)[0]

X = training_data[:,1:]
N = np.shape(X)[1]
X_Test = test_data
Y = training_data[:,:1]
Y = np.array(Y).astype(int)
Y=np.concatenate(Y,axis=0)
print(Y)
# Out:
# [3 1 3 ... 1 2 2]

# %%
# TODO [4]: Draw a scatter plot for traning data, where each class is coloured by the colour corresponding 
#           to its index in the colors array.
# Class 1 should be coloured in red, Class 2 should be coloured in green, and Class 3 should be coloured in blue.
# Hint: We have done a similar plot in the previous lab. What operation do we need to select training data 
#       belonging to a certain class?

colors = ['r', 'g', 'b', 'c', 'y']

class1 = X[Y==1]
class2 =  X[Y==2]
class3 = X[Y==3]

#print(features_rect) 

# ------------------------------------------------------------------------------------------------------

fig = plt.figure()
ax = fig.add_subplot('111')

# ------------------------------------------------------------------------------------------------------
ax.scatter(class1[:,0],class1[:,1], color=colors[0], label = "class1")

# ------------------------------------------------------------------------------------------------------
ax.scatter(class2[:,0],class2[:,1], color=colors[1], label = "class2")

# ------------------------------------------------------------------------------------------------------
ax.scatter(class3[:,0],class3[:,1], color=colors[2], label = "class3")


# ------------------------------------------------------------------------------------------------------

ax.set_title('Training Data')
ax.set_xlabel('feature 1')
ax.set_ylabel('feature 2')

handles, labels = ax.get_legend_handles_labels()
unique = list(set(labels))
handles = [handles[labels.index(u)] for u in unique]
labels = [labels[labels.index(u)] for u in unique]

ax.legend(handles, labels)

plt.show()

# %%
## What do you notice about the plot? (Write everything you can think of)
'''
    Your Answer:
''' 
#They are mainly separated and small overlapping
# Out:
# '\n    Your Answer:\n'

# %% [markdown]
# ### Bayesian Classifier
# The Bayesian Classifier calculates the probability of the test point belonging to each class, then the class with highest probability is assigned to the test point.
#
# Classification of $x_{test}$ = $argmax_{i} P\big(C_i|x_{test}\big)$ = $argmax_{i} P(x|C_i) * P(C_i)$
#
# * $P(C_i|x_{test})$: Posterior probability
# * $P(x|C_i)$: Class-conditional probability (or distribution)
# * $P(C_i)$: Class apriori probability
#
# **Note that** $P(C_i|x_{test}) \neq P(x_{test}|C_i) * P(C_i)$. Instead,  $P(C_i|x_{test}) = \frac{P(x_{test}|C_i) * P(C_i)}{P(x_{test})}$. However, when we compare multiple classes, the denominator $P(x_{test})$ is independent of the class $i$ and can be regarded as normalizing factor.
#
# **We start by** computing statistical parameters about each class from the data.
#
# For each class, we are interested in **three** parameters that will be used for calculating the Gaussian class-conditional distribution and the posterior probability.
#
# These parameters are:
#
# |||
# |:-|:-|
# |**Class Apriori Probability: ($P_C$)**| A scalar; the probability of class occurence (how frequent this class appears in the training data)|
# |**Class Mean: ($\mu$)**| A vector of shape $(N \times 1)$, it is the expected value (mean) calculated from the training points of each class.|
# |**Class Covariance Matrix: ($\Sigma$)**| A square symmetric matrix of shape $(N \times N)$ representing the covariances between all the feature calculated from the training points of the class. <br/> For example: Matrix element $\sigma^2_{12}$ is the covariance between the 1st and the 2nd features|

# %%
#pClasses = [np.shape(class1)[0]/M,np.shape(class2)[0]/M,np.shape(class3)[0]/M] 
#uniqueY =np.unique(Y)
    #print(uniquelabel)
estimate_covariances = []    
pClasses=[]
estimate_means=[]
# for i in uniqueY:
#     pClasses.append(X[Y==i]/M)
#     estimate_means.append(np.mean(X[Y==i], axis=0))
#     estimate_covariances.append(np.cov(X[Y==i].T))
# A list of size (numClasses, 1) containing the a priori probabilities of each class in the training set.


# A numpy array of size (numClasses, N) containing the mean points of each class in the training set. 
                    # HINT: USE NP.MEAN

# A numpy array of size (numClasses, N, N) containing the covariance matrices of each class in the training set.
                          # HINT: USE NP.COV (Pay attenention for what it takes as an argument)
                             
for classIndex in range(numClasses):
    print(classIndex)
    # TODO [5]: Estimate the parameters of the Gaussian distributions of the given classes.
    # Fill pClasses, estimate_means, and estimate_covariances in this part 
    # Your code should be vectorized WITHOUT USING A SINGLE FOR LOOP.
    pClasses.append(np.shape(X[Y==classIndex+1])[0]/M)
    estimate_means.append(np.mean(X[Y==classIndex+1], axis=0))
    estimate_covariances.append(np.cov(X[Y==classIndex+1].T))
    

print(np.shape(pClasses))
print(np.shape(estimate_means))
print(np.shape(estimate_covariances))

estimate_means = np.array(estimate_means)
estimate_covariances = np.array(estimate_covariances)
# Out:
# 0
# 1
# 2
# (3,)
# (3, 2)
# (3, 2, 2)

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
assert len(pClasses) == numClasses,\
        'Incorrect class apriori probability list, it should be of length {}'.format(len(pClasses))
assert round(np.sum(pClasses))==1,\
        'Sum of apriori probabilities should be 1, found {}'.format(np.sum(pClasses))

assert estimate_means.shape == (numClasses, N),\
        'Incorrect estimated means, it should be of shape {}'.format((numClasses, N))
assert estimate_covariances.shape == (numClasses, N, N),\
        'Incorrect estimate covariance matrices, it should be of shape {}'.format((numClasses, N, N))

# %% [markdown]
# **The second step** in the classifier is to calculate the class-conditional density using the Gaussian destribution:
#
# $P(x|C_i) = \mathcal{N}(x; \mu_i, \Sigma_i) = \frac{1}{(2\pi)^{\frac{N}{2}}|\Sigma_i|^{\frac{1}{2}}} exp\big(\frac{-1}{2}(x-\mu_i)^T\Sigma^{-1}_{i}(x-\mu_i)\big)$

# %%
# TODO 6: Implement the multivariate normal gaussian distribution with parameters mu and sigma, and return the
#  value in prob.
def multivariate_normal_gaussian(X, mu, sigma):
    #print(X)
    #print(mu)
    #print(sigma)
    N=np.shape(mu)[0]
    m1=np.matmul(np.subtract(X,mu).T , np.linalg.pinv(sigma))
    m2=np.matmul(m1,np.subtract(X,mu))
    #print(m2[0,0])
    #print((2*math.pi)**(N/2) * np.power(np.linalg.norm(sigma),0.5))
    prob =np.exp(m2/-2) /((2*math.pi)**(N/2) * np.power(np.linalg.norm(sigma),0.5)) 
    return prob

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
np.random.seed(90)
assertion_x = np.random.rand(3).reshape(-1,1)
assertion_mu = np.random.rand(3).reshape(-1,1)
assertion_sigma = np.random.rand(9).reshape(3,3)
assertion_probability = multivariate_normal_gaussian(assertion_x, assertion_mu, assertion_sigma)[0][0]
assertion_probability = round(assertion_probability, 1)
print(assertion_probability)

assert assertion_probability == 7.8,\
    'Incorrect Gaussian Probability calculated'
# Out:
# 1.3
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-63-8f966076fcdc> in <module>
#      10
#      11 assert assertion_probability == 7.8,\
# ---> 12     'Incorrect Gaussian Probability calculated'
#
# AssertionError: Incorrect Gaussian Probability calculated

# %% [markdown]
# **The final step** is to go for each test point, calculate its posterior probability against each class, then classify it to the class with the highest posterior probability.

# %%
# TODO [7]: Apply the Bayesian Classifier to predict the classes of the test points.
predicted_classes = [] # predicted_classes: A numpy array of size (K, 1) where K is the number of points in the test set. Every element in this array
                       # contains the predicted class of Bayes classifier for this test point.

for i in range(X_Test.shape[0]):
    print("For test point:", X_Test[i])
    classProbabilities = np.zeros(numClasses)
    for j in range(numClasses):
        #print(j)
        classprob=multivariate_normal_gaussian(X_Test[i],estimate_means[j],estimate_covariances[j])*pClasses[j]
        classProbabilities[j]=classprob
    # TODO [7.A]: Compute the probability that the test point X_Test[i] belongs to each class in numClasses.
    #  Fill the array classProbabilities accordingly.
    max_index = np.argmax(classProbabilities)
    predicted_classes.append(max_index+1)
    
    # TODO [7.B]: Find the prediction of the test point X_Test[i] and append it to the predicted_classes array.
    

    print('Class Probabilities: ', classProbabilities)  # the first class is the left most in the scatter plot
    print("Predicted class is :", predicted_classes[i])
    print("******************************************************************************")
# Out:
# For test point: [10.70141426  3.87253627]
# Class Probabilities:  [3.43381201e-12 2.93026653e-17 4.90396763e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.81831787 -5.00977814]
# Class Probabilities:  [1.99123003e-02 2.18109563e-10 3.83073909e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.57071936  9.96036181]
# Class Probabilities:  [1.02556823e-19 1.86462302e-03 1.06043816e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 4.94309043 -0.01539406]
# Class Probabilities:  [2.53035614e-06 2.65234969e-08 1.12097339e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.26082551 -0.61349358]
# Class Probabilities:  [8.06614974e-06 6.80575452e-08 9.30663523e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.98901139 16.86268221]
# Class Probabilities:  [5.80023512e-36 4.22316249e-04 3.27286131e-17]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.2796485  -3.38655342]
# Class Probabilities:  [2.86492034e-03 1.59092562e-07 1.64135969e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 2.60503344 -0.24206319]
# Class Probabilities:  [1.10089754e-04 2.66038496e-06 4.41834720e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.84312621 12.42130394]
# Class Probabilities:  [9.34377288e-20 7.12483981e-03 3.34916264e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-6.52253054 10.13668928]
# Class Probabilities:  [4.05223977e-25 1.91603066e-06 1.46873282e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 5.59472055 -4.37938379]
# Class Probabilities:  [3.68506758e-09 4.81673862e-12 2.27557109e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.98596817 -0.73837508]
# Class Probabilities:  [1.03325833e-03 1.62972719e-06 8.72867206e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-2.23908496 13.21358765]
# Class Probabilities:  [9.58744996e-26 4.53113152e-03 7.43382673e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -6.7789975 -11.0163502]
# Class Probabilities:  [1.40725481e-03 2.19461061e-20 4.07809288e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.59545273 -0.41955489]
# Class Probabilities:  [7.41532667e-04 1.46066101e-05 9.02088247e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.36129364 -5.42102971]
# Class Probabilities:  [6.37975950e-15 2.47261180e-17 4.68007007e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.52848225 -7.42893531]
# Class Probabilities:  [2.52561125e-03 7.93321641e-12 2.50376167e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.56086046 -9.03278997]
# Class Probabilities:  [3.36008797e-03 3.63576147e-15 9.80523757e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.02188067 -0.93735269]
# Class Probabilities:  [8.14493869e-09 9.55769072e-12 1.03842732e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.1509862  1.43750612]
# Class Probabilities:  [1.16686426e-10 1.52498435e-14 4.28112457e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.71007022 10.6797775 ]
# Class Probabilities:  [7.94296433e-19 1.34602348e-02 5.71071650e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.76302456 -5.55297678]
# Class Probabilities:  [2.21779953e-02 9.06106431e-12 4.43244724e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.89883417 -5.39496672]
# Class Probabilities:  [2.13720159e-02 9.12283512e-12 3.92903002e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.03379007 2.71590677]
# Class Probabilities:  [4.21221395e-09 8.64853252e-12 4.42948953e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.89215726 -2.59460822]
# Class Probabilities:  [3.04087674e-03 2.11152201e-09 2.10853636e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.11834647  4.91066223]
# Class Probabilities:  [1.35262073e-10 1.15246889e-04 6.98241817e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 6.45717699 -2.43934454]
# Class Probabilities:  [6.56593972e-09 8.20339177e-12 7.17283152e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.56547098 4.9207542 ]
# Class Probabilities:  [2.68663046e-07 1.50280682e-03 1.67426854e-04]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.26265631 6.5794146 ]
# Class Probabilities:  [2.92440499e-09 4.73977664e-03 1.99664067e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.70832433 -3.11174424]
# Class Probabilities:  [3.99459425e-05 2.94759495e-08 2.25005894e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -9.10836917 -11.76552446]
# Class Probabilities:  [1.05625757e-03 1.52756006e-25 3.68178506e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.81726658 -5.3687788 ]
# Class Probabilities:  [2.14619641e-02 1.17810468e-11 4.69193569e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.30975347  9.75343174]
# Class Probabilities:  [2.23190653e-15 1.98149891e-02 2.44420050e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-7.58893623 -3.93631034]
# Class Probabilities:  [8.64060755e-04 3.68277245e-14 3.26808013e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-11.3843618 -12.1472865]
# Class Probabilities:  [3.05270671e-04 2.47857124e-31 2.91333066e-19]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.15303864 -5.99521012]
# Class Probabilities:  [1.23076435e-11 3.63022412e-14 4.91074215e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [0.88072334 9.72115039]
# Class Probabilities:  [2.62741986e-14 1.19253446e-02 1.01189162e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.3263618 8.7977202]
# Class Probabilities:  [1.96827914e-12 7.86807449e-03 8.02949496e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.70501109 11.56174259]
# Class Probabilities:  [1.60055004e-25 1.98259114e-04 3.99725979e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.12643357 -4.83616859]
# Class Probabilities:  [1.66149099e-02 1.02779711e-09 1.38074492e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 4.05674244 12.57155861]
# Class Probabilities:  [1.84388554e-17 4.07306389e-05 2.91003143e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -4.30106198 -10.6042502 ]
# Class Probabilities:  [2.54098335e-04 9.07671477e-17 1.13090985e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 5.11776496 -0.99143917]
# Class Probabilities:  [1.12070066e-06 4.52366488e-09 1.08019809e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 6.05493358 -5.87189841]
# Class Probabilities:  [2.47072619e-11 6.41033590e-14 5.65557411e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.74275953 -3.97527522]
# Class Probabilities:  [1.53286782e-06 1.03841045e-09 2.14872251e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.02170247 -5.57244813]
# Class Probabilities:  [2.07772112e-02 4.48303440e-11 1.67450427e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.27810154 -3.99998321]
# Class Probabilities:  [9.32910807e-03 5.91952622e-11 5.13043392e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.80988364 3.43699512]
# Class Probabilities:  [2.42810389e-07 6.80375371e-08 3.96432111e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.6311676  1.76165524]
# Class Probabilities:  [6.72812739e-10 2.50338964e-13 5.09912546e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.73761305 -6.16978647]
# Class Probabilities:  [2.22416081e-02 2.49287102e-12 2.60494871e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.28411495 -2.28452888]
# Class Probabilities:  [2.16081981e-21 3.36207976e-27 5.30716732e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.47775397 -0.10213091]
# Class Probabilities:  [5.52776992e-04 7.70697460e-06 1.89947643e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.42758688 -7.1513932 ]
# Class Probabilities:  [1.49404128e-02 5.37454436e-13 1.58384520e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.71805696 -8.49355483]
# Class Probabilities:  [1.83214198e-04 1.40507571e-12 1.81068469e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.07056432 13.27106731]
# Class Probabilities:  [4.49973308e-29 4.03427976e-04 2.35378499e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.82594718 -9.52426172]
# Class Probabilities:  [1.98392909e-04 2.69441883e-14 7.87499025e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.2893587   1.35319816]
# Class Probabilities:  [2.49775695e-12 3.77118282e-17 2.05999619e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.13419282  9.00152907]
# Class Probabilities:  [9.81475084e-15 1.75337941e-02 3.20228298e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.29226867  7.97517886]
# Class Probabilities:  [3.51024164e-12 1.60683616e-02 5.21730259e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 9.46997908 -1.99299457]
# Class Probabilities:  [3.10152547e-13 4.59947931e-17 2.72825283e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.05416915 -2.47425901]
# Class Probabilities:  [4.84627386e-03 6.39578141e-07 9.96910903e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 2.21553241 12.53863186]
# Class Probabilities:  [1.04240626e-18 1.48108298e-03 9.34663762e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.85953786 -0.76518719]
# Class Probabilities:  [2.67260051e-11 4.91711985e-15 5.48521573e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.11560394 -2.51521659]
# Class Probabilities:  [3.34864765e-06 5.70687050e-09 5.50125099e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.88633577 -7.73994173]
# Class Probabilities:  [1.70792024e-02 2.77645206e-15 4.58998865e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.79933965  5.31322455]
# Class Probabilities:  [3.27590144e-09 3.21683690e-03 2.23799716e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.34271378 16.23529621]
# Class Probabilities:  [1.31132178e-28 3.79961563e-04 1.94595788e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.55913997 10.48707791]
# Class Probabilities:  [3.40148944e-15 6.05165623e-03 4.51751957e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.86122888  7.15903434]
# Class Probabilities:  [4.07706014e-12 7.70581750e-03 2.05150415e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.38794864  4.18558645]
# Class Probabilities:  [7.59364743e-09 2.37467978e-04 5.26259059e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-9.52727338 -7.21208436]
# Class Probabilities:  [1.77293710e-03 5.59182268e-21 1.41545657e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.98956144 -7.5666012 ]
# Class Probabilities:  [1.50861112e-02 5.15329678e-14 3.37680364e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.75405923 -5.30192282]
# Class Probabilities:  [8.98456025e-04 1.71556495e-17 6.99410235e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.94621632 -6.88516599]
# Class Probabilities:  [1.34902836e-02 2.79102035e-12 5.03533252e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31994442 -2.63044722]
# Class Probabilities:  [2.19544087e-03 6.68572549e-10 8.93398146e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-9.36297948 -8.56822792]
# Class Probabilities:  [3.74023746e-03 3.99806084e-22 4.00974714e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.81585174 -3.0905699 ]
# Class Probabilities:  [8.89962472e-03 8.91133588e-09 1.25905344e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.48384894 -2.13782697]
# Class Probabilities:  [3.14716773e-17 5.29088111e-22 4.77436628e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [7.38337554 4.66707989]
# Class Probabilities:  [7.63767427e-09 5.27619675e-10 1.42672036e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.19811716 -3.20869437]
# Class Probabilities:  [1.07723666e-02 2.08426397e-08 3.37479167e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.73664819 -5.64026754]
# Class Probabilities:  [2.23866935e-02 7.99758366e-12 4.30946727e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.16135146 8.11909452]
# Class Probabilities:  [1.80242069e-10 4.22030017e-06 2.30203822e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.93192373 -7.90304636]
# Class Probabilities:  [1.20294081e-02 2.61582598e-14 2.44846211e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.44663034 -1.10812617]
# Class Probabilities:  [6.84222238e-11 2.09371944e-14 6.30188193e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.41266737  -6.02755366]
# Class Probabilities:  [1.34439334e-04 9.94708571e-22 3.91817600e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-10.55452885  -6.98597699]
# Class Probabilities:  [3.14379379e-04 4.82611467e-23 1.00190058e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.16708742 -4.41114641]
# Class Probabilities:  [1.69517727e-03 2.37515243e-08 9.71308197e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [6.83499316 3.0513492 ]
# Class Probabilities:  [5.32184493e-08 1.43883895e-09 4.88560999e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.3218284   8.03062152]
# Class Probabilities:  [2.69769453e-12 1.63245915e-02 4.61633030e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.67262506 -3.63638033]
# Class Probabilities:  [1.24057837e-02 2.01580630e-08 6.20675551e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.23839346 15.50904654]
# Class Probabilities:  [8.61106803e-27 7.92156139e-04 1.51661846e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.85415463 -9.49083878]
# Class Probabilities:  [4.83568243e-06 1.90100013e-13 1.10032258e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.57934474 14.05416562]
# Class Probabilities:  [1.87549087e-25 5.65614753e-03 1.00084661e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.08121918 9.02118593]
# Class Probabilities:  [5.94961992e-13 9.98650146e-03 4.33204761e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.54545494 13.38470402]
# Class Probabilities:  [1.97751034e-28 9.09530193e-04 4.83036257e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.25685021 12.98458764]
# Class Probabilities:  [1.06399366e-21 8.02296677e-03 4.46429278e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.49117921 -2.09111202]
# Class Probabilities:  [1.13998609e-11 4.22966490e-15 4.56045980e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.6377611  2.59220877]
# Class Probabilities:  [5.35478297e-11 3.77875021e-15 2.15568625e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.99632131 -0.81831291]
# Class Probabilities:  [4.62117105e-10 2.22759697e-13 8.02260616e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.8066989  12.60496257]
# Class Probabilities:  [2.28813789e-18 5.52368658e-04 1.26183730e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.14054117 13.99755821]
# Class Probabilities:  [1.07208832e-24 5.46835267e-03 2.06526153e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.0622924  -4.14345298]
# Class Probabilities:  [1.53100821e-02 4.46929798e-09 2.49490183e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.73588097 -8.59503648]
# Class Probabilities:  [1.03137198e-02 5.03763894e-16 1.96838905e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.87691909 -8.51465367]
# Class Probabilities:  [7.23352376e-03 6.45501802e-15 1.17633547e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.30461631 -2.42881748]
# Class Probabilities:  [1.21285645e-11 5.83175266e-15 4.30144470e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.92551153  9.38904848]
# Class Probabilities:  [2.43260556e-16 1.20104397e-02 5.03143317e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-8.06681967 -9.76445434]
# Class Probabilities:  [5.92030468e-03 5.43652222e-21 1.83562862e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.24410989 -8.18831047]
# Class Probabilities:  [8.49965761e-03 1.71856194e-19 1.20683693e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.37602904 -5.99069434]
# Class Probabilities:  [2.19844727e-02 7.22221580e-13 9.04455305e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.22386765 -4.85135398]
# Class Probabilities:  [1.59980324e-06 5.33067788e-10 8.89951127e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.55406083 -2.89224039]
# Class Probabilities:  [3.40122818e-04 1.71937277e-07 1.16441146e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.69049165 13.4044702 ]
# Class Probabilities:  [3.81690548e-20 4.56807677e-04 1.65601133e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.53571156 10.66187251]
# Class Probabilities:  [7.24684559e-20 6.91929305e-03 1.59516486e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.96782552 -4.31305255]
# Class Probabilities:  [5.22498273e-07 3.49689393e-10 1.81743799e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.00081432  8.87275799]
# Class Probabilities:  [2.16517449e-15 1.07610995e-02 1.12103682e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.35696677 -3.77423836]
# Class Probabilities:  [7.34796197e-03 7.41385461e-11 4.98343401e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.48811048 -3.16156655]
# Class Probabilities:  [5.89887314e-11 5.57115454e-14 3.99554625e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.06573364 -13.36721214]
# Class Probabilities:  [9.74513869e-06 1.72772613e-22 1.37961546e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.1851141 2.6171304]
# Class Probabilities:  [1.05225001e-06 2.28770164e-07 5.87407911e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.27828524 1.31354615]
# Class Probabilities:  [1.42901490e-09 7.97222748e-13 6.68655870e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.79242965 1.64031539]
# Class Probabilities:  [1.19751468e-05 2.87752458e-06 5.86645149e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.138666   6.8602675]
# Class Probabilities:  [2.44866477e-10 1.11006210e-02 3.13826762e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 5.78244942 -9.12198008]
# Class Probabilities:  [2.96102661e-15 9.50508408e-17 6.94678772e-06]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.60435329 -5.38072375]
# Class Probabilities:  [2.35832853e-07 9.31065509e-11 6.47244765e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.85525938 -6.34543458]
# Class Probabilities:  [1.65287169e-02 1.14469881e-11 1.05818224e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.08621387  1.9348786 ]
# Class Probabilities:  [8.87157356e-17 1.79715763e-24 1.04849198e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.97701781 -8.26247269]
# Class Probabilities:  [4.67824025e-03 9.43481689e-14 8.40013638e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.3366769  1.22185752]
# Class Probabilities:  [0.0001677  0.00012824 0.00054429]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-9.28532526 -9.4355402 ]
# Class Probabilities:  [3.96747473e-03 5.66292118e-23 1.38727993e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.66429005 11.01189494]
# Class Probabilities:  [4.21928290e-16 4.92167166e-03 1.71121795e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.08966182 -1.69228564]
# Class Probabilities:  [3.17750116e-03 3.25067133e-07 6.66215066e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.33789356 -2.66619436]
# Class Probabilities:  [6.76689705e-09 8.61700599e-12 6.54308789e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.56901228  5.51033591]
# Class Probabilities:  [1.02704866e-08 5.89335296e-03 9.62688305e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.99286099 -4.68078563]
# Class Probabilities:  [3.67130333e-06 1.09373437e-09 9.19911558e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.80021733 11.42437424]
# Class Probabilities:  [1.22943560e-20 1.12931846e-02 1.02153361e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.16929961 -4.74585978]
# Class Probabilities:  [1.63946446e-04 7.90487698e-09 2.64789722e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.15245262 14.77479741]
# Class Probabilities:  [2.57908235e-26 2.99883807e-03 3.59944622e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-11.57247905  -6.73922446]
# Class Probabilities:  [3.37310395e-05 2.67664268e-25 6.06975058e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.60476346  4.55773513]
# Class Probabilities:  [1.16981333e-11 2.85358713e-06 4.95746345e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 7.91493717 -4.93203896]
# Class Probabilities:  [1.77079808e-13 4.27563690e-16 9.13662031e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.40280867 -4.97280708]
# Class Probabilities:  [1.62001115e-02 5.97968500e-12 2.06226944e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [2.04297042 2.03014309]
# Class Probabilities:  [3.75504978e-05 8.12583771e-05 1.84061913e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.21122011 -10.70086807]
# Class Probabilities:  [1.50003783e-03 3.72697600e-19 2.44801966e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.53064612 -8.83892725]
# Class Probabilities:  [7.81903202e-03 4.85325611e-16 2.08446517e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.30022088 11.20197432]
# Class Probabilities:  [2.27255520e-15 3.52673247e-04 3.99388002e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.52678262 11.00539841]
# Class Probabilities:  [4.57566007e-17 1.31755922e-02 5.49434767e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [6.2375991  2.80421505]
# Class Probabilities:  [1.76146359e-07 9.88808205e-09 5.81199952e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.1883182  -1.89030168]
# Class Probabilities:  [5.29500398e-05 6.87368168e-12 1.81024076e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.60122702 15.01466265]
# Class Probabilities:  [4.58474594e-28 3.02120788e-03 6.91427160e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.34641109 -4.86072033]
# Class Probabilities:  [5.06346153e-03 6.75672774e-09 1.73953746e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.63822042 -5.45296469]
# Class Probabilities:  [7.79563333e-12 2.10511952e-14 8.07193047e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [6.54807184 1.19913258]
# Class Probabilities:  [1.11351006e-07 7.18220840e-10 1.04565005e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [11.7595198   0.33353443]
# Class Probabilities:  [1.93151312e-15 2.31251945e-21 6.12673419e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.04384705  3.3153199 ]
# Class Probabilities:  [2.11395230e-11 7.77913107e-16 1.13781044e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.72322077 2.89573292]
# Class Probabilities:  [4.54887731e-06 1.11327624e-05 3.21940624e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.23412033 10.5086633 ]
# Class Probabilities:  [4.94746971e-22 5.82855264e-04 9.99313203e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [2.75812898 9.80988701]
# Class Probabilities:  [2.71947394e-13 1.19824581e-03 4.36058260e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [5.71709878 0.05250004]
# Class Probabilities:  [5.02181793e-07 3.04847172e-09 1.22772901e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.4383003  14.46253234]
# Class Probabilities:  [2.51063005e-33 1.10423165e-04 4.66261045e-16]
# Predicted class is : 2
# ******************************************************************************
# For test point: [10.31980548  5.65793048]
# Class Probabilities:  [8.44370593e-12 6.47055477e-16 1.47721926e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.37524372  -7.74958537]
# Class Probabilities:  [7.95694817e-04 1.91114105e-23 6.99388115e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.60020077 -5.42453553]
# Class Probabilities:  [2.19407538e-02 1.75205160e-11 6.72140332e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.20850522 -0.73094364]
# Class Probabilities:  [4.87531423e-05 5.10923360e-07 6.04512058e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.67511969 -0.45766944]
# Class Probabilities:  [7.74336599e-11 1.72867735e-14 6.27184129e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.84241029 -2.07200837]
# Class Probabilities:  [4.96043539e-03 2.49520318e-07 9.06681429e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.02815393 0.12504483]
# Class Probabilities:  [2.21066833e-06 2.50552511e-08 1.13295521e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.63527967 10.82193815]
# Class Probabilities:  [9.20273980e-16 5.27687657e-03 2.46633705e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.69546404 1.63793279]
# Class Probabilities:  [3.52701968e-06 3.39408095e-07 7.94239635e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.20495861 -8.54182529]
# Class Probabilities:  [4.26257485e-03 2.88608061e-14 3.81716838e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.85664823  8.27107861]
# Class Probabilities:  [2.30110378e-19 1.01708980e-05 2.10793222e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.43266395 -7.3131535 ]
# Class Probabilities:  [1.88741823e-02 2.91803950e-14 1.94622896e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.43743782 10.57358038]
# Class Probabilities:  [3.19603361e-14 3.04390506e-04 1.56061105e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.51691079 1.90895905]
# Class Probabilities:  [4.04221141e-06 7.05335052e-07 6.87541073e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.95393725 -2.06290005]
# Class Probabilities:  [5.02069309e-05 1.11550560e-07 4.01467075e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.17022706 -4.71914956]
# Class Probabilities:  [1.03950052e-02 4.50156132e-09 6.39455411e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [6.87943361 0.56763302]
# Class Probabilities:  [3.99965147e-08 1.07002564e-10 1.11631544e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.90155375 -2.49446135]
# Class Probabilities:  [1.07089900e-12 3.45379453e-16 3.09341539e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.75309704 10.13350214]
# Class Probabilities:  [3.64755222e-15 1.28122588e-02 4.05802932e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-6.83046209 -9.95463151]
# Class Probabilities:  [4.76757639e-03 3.77960369e-19 2.36797920e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.48084666 2.21690041]
# Class Probabilities:  [1.51891155e-08 5.68376487e-11 6.50092471e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.51484158 16.05856446]
# Class Probabilities:  [1.90963461e-36 1.72856067e-04 2.72575378e-17]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.29796106 -1.51960377]
# Class Probabilities:  [3.30626224e-03 1.17393496e-06 2.35234138e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.04675075 14.39325425]
# Class Probabilities:  [3.62717305e-24 2.15607162e-03 2.84808063e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.33223697 -7.63241344]
# Class Probabilities:  [4.83823661e-03 1.47974441e-12 5.66114404e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.38944943 -9.23325113]
# Class Probabilities:  [2.25351707e-03 3.18377216e-15 9.78465446e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.74176393 -5.02512921]
# Class Probabilities:  [1.99155838e-02 2.90883499e-11 7.16603048e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.41004634 -5.5997003 ]
# Class Probabilities:  [6.10691222e-03 2.28710164e-15 1.54392284e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.09797276 -7.51282903]
# Class Probabilities:  [8.61410749e-03 1.73246266e-18 4.07148911e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.65055    14.73266536]
# Class Probabilities:  [2.71731360e-24 9.08747784e-04 2.06541434e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.15219027 3.63873026]
# Class Probabilities:  [3.58472381e-06 8.68611944e-04 3.45136451e-04]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.25543293  9.24132191]
# Class Probabilities:  [2.56415084e-15 1.71914016e-02 1.76845945e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.3701864  10.61688349]
# Class Probabilities:  [1.53868688e-19 8.17249128e-03 2.29908823e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-11.26329666  -7.92344489]
# Class Probabilities:  [2.20953657e-04 8.67836281e-26 4.09675051e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [1.37598504 5.76529642]
# Class Probabilities:  [3.07184565e-08 2.93497641e-03 5.87103921e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.88140712 -3.02402962]
# Class Probabilities:  [8.27443962e-03 8.86844708e-09 1.15587775e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.66886091 -1.94857083]
# Class Probabilities:  [3.23275622e-03 8.32349023e-08 2.38987274e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.21817753 10.22511294]
# Class Probabilities:  [8.40469732e-16 1.69583717e-02 1.87427392e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.01734447 -3.01633766]
# Class Probabilities:  [2.32913608e-05 2.12639358e-08 2.78449204e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.45242039 2.18725534]
# Class Probabilities:  [2.50752735e-05 5.50480550e-05 2.28820112e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.81338366 -3.04810313]
# Class Probabilities:  [3.42002720e-05 2.79792613e-08 2.46314773e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.35226244  7.94145336]
# Class Probabilities:  [5.27684554e-13 1.32737563e-02 1.35201845e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.32479122 -9.12757714]
# Class Probabilities:  [1.75284920e-04 1.48771146e-13 3.06276325e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.99032273 -0.46466519]
# Class Probabilities:  [1.17517851e-14 9.42108063e-20 1.23711561e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.52557256 -5.00051738]
# Class Probabilities:  [3.24629104e-03 5.35419988e-15 1.90116471e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31739532 -7.08917772]
# Class Probabilities:  [1.99302907e-02 6.82882974e-14 3.18153143e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-2.87484239  6.36256125]
# Class Probabilities:  [9.98672807e-12 1.99976759e-03 1.19761043e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.70055404 17.81508726]
# Class Probabilities:  [1.73326742e-38 1.88566530e-04 2.29441173e-18]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.83913631 -3.92362328]
# Class Probabilities:  [1.47612777e-02 1.81592389e-09 7.85276989e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31785661 -8.22012729]
# Class Probabilities:  [1.14686061e-02 4.29785878e-15 7.63358447e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 4.41220473 -0.78866093]
# Class Probabilities:  [5.64489993e-06 3.74221779e-08 9.56344554e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 5.86521872 -3.83801546]
# Class Probabilities:  [4.25377460e-09 5.60056271e-12 3.39114802e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.27975169 -5.40685681]
# Class Probabilities:  [9.03964421e-03 9.78572886e-10 3.10799029e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.44252378  5.04836557]
# Class Probabilities:  [7.50046432e-12 2.48069473e-16 2.40096126e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.10454519 -8.59923558]
# Class Probabilities:  [7.69170875e-03 2.89825152e-15 6.77771122e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.79291315 9.94727029]
# Class Probabilities:  [8.71016429e-15 1.26059938e-02 6.04349835e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 6.54304649 -2.92516109]
# Class Probabilities:  [2.33278022e-09 2.80053391e-12 5.61052636e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.39028133 12.45758209]
# Class Probabilities:  [2.51238794e-20 9.37360314e-03 1.85717898e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [9.43284293 1.63188371]
# Class Probabilities:  [5.59564874e-11 4.53702692e-15 3.45790237e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.09569772 1.68119391]
# Class Probabilities:  [8.17701673e-05 1.42787872e-04 9.73366290e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.85994525 -1.67404675]
# Class Probabilities:  [2.18166124e-10 1.21590486e-13 6.88434382e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.72753408  1.0240291 ]
# Class Probabilities:  [3.46250697e-13 2.31796250e-18 1.53645264e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.36857973 2.77908536]
# Class Probabilities:  [1.26729686e-05 1.08875610e-04 1.59977217e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.46358952 -4.88042874]
# Class Probabilities:  [1.94136734e-14 4.41083843e-17 7.46616913e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-8.6591206 -3.386283 ]
# Class Probabilities:  [6.11307240e-05 1.30053059e-15 2.91789136e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.4916236  0.68401163]
# Class Probabilities:  [4.82915309e-10 1.55689773e-13 6.79770243e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.09417452 -10.83373126]
# Class Probabilities:  [1.51036971e-03 1.82454547e-26 1.49177957e-16]
# Predicted class is : 1
# ...
# For test point: [10.36682284 -2.94025912]
# Class Probabilities:  [7.31628365e-16 9.84626869e-20 8.89745029e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 9.17686513 -0.67617114]
# Class Probabilities:  [9.81304544e-12 1.20096284e-15 4.66061787e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.56032018 10.89248968]
# Class Probabilities:  [2.98395900e-15 1.45018644e-03 4.58960221e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [0.8138255 6.3426885]
# Class Probabilities:  [3.91203163e-09 6.05594715e-03 1.73856069e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.58026808  9.29140022]
# Class Probabilities:  [9.27563517e-16 1.48503682e-02 1.01058693e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.85860141 -1.00596681]
# Class Probabilities:  [1.86750403e-11 3.59441532e-15 5.25335514e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.81652326 -2.73427081]
# Class Probabilities:  [4.31575154e-05 4.71559233e-08 2.86893129e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.91081684 -2.76984203]
# Class Probabilities:  [4.80217617e-03 4.10588367e-07 1.06060090e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.06815545  9.53292586]
# Class Probabilities:  [1.81913235e-19 7.84730430e-04 9.39119685e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [7.34079799 3.06978894]
# Class Probabilities:  [1.92475391e-08 2.07460136e-10 4.45021287e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.64032058 12.0068455 ]
# Class Probabilities:  [8.40836220e-22 1.07025131e-02 3.52209420e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [11.02141864 -0.12519999]
# Class Probabilities:  [1.90810828e-14 1.18418547e-19 1.24302509e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.83660161 7.63741536]
# Class Probabilities:  [4.01588526e-10 8.57054565e-04 1.65073583e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.55253392 -2.86889414]
# Class Probabilities:  [1.30169344e-03 3.41998745e-07 4.96911217e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.97166844 -3.22481456]
# Class Probabilities:  [2.23834009e-06 2.41301475e-09 3.70935041e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.98490968 -4.84749576]
# Class Probabilities:  [1.57399808e-02 1.24381191e-09 1.71231344e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.10588756 1.58507517]
# Class Probabilities:  [1.49172290e-10 2.20022850e-14 4.22689968e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.99945013 -3.95313184]
# Class Probabilities:  [5.06106658e-08 5.62977551e-11 2.98043935e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.71883232 15.1537229 ]
# Class Probabilities:  [2.86602131e-25 6.11611350e-04 6.77660853e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.33163346  9.72288532]
# Class Probabilities:  [2.43724733e-15 1.98653137e-02 2.51787649e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [11.04296746  1.25113376]
# Class Probabilities:  [1.40646698e-13 4.68552078e-19 1.12328225e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.22009129  9.65386874]
# Class Probabilities:  [4.19229606e-15 1.95628004e-02 3.28880648e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.70876068  2.17594789]
# Class Probabilities:  [1.57670868e-05 2.48615810e-04 3.01569181e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.51045177 7.56673947]
# Class Probabilities:  [7.65583060e-10 2.29610810e-05 4.25663544e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.29825485 13.66342044]
# Class Probabilities:  [1.75964444e-25 6.31336978e-03 1.01472707e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-9.72864588 -6.0121161 ]
# Class Probabilities:  [4.42183560e-04 3.52081658e-20 2.77026451e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.48899942 17.98748437]
# Class Probabilities:  [9.70355488e-37 1.92259898e-04 7.75379719e-18]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.77337683  7.24172304]
# Class Probabilities:  [2.36333690e-11 1.28050449e-02 8.40759555e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.05007773 15.12157932]
# Class Probabilities:  [9.3954925e-31 1.7272102e-03 5.8402041e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.79351842 -4.31693215]
# Class Probabilities:  [1.72864841e-02 9.23010236e-10 6.63050421e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.23987052 0.84895898]
# Class Probabilities:  [1.84012005e-08 3.72099638e-11 1.00629160e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.30596448 -3.23156572]
# Class Probabilities:  [4.66854854e-04 4.13428358e-13 9.08981528e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.28227684 -5.29628215]
# Class Probabilities:  [1.92381918e-02 4.19689996e-12 2.02489718e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.84284999 -4.65776943]
# Class Probabilities:  [4.93202392e-13 9.62984248e-16 1.19898503e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.36231452 14.65339584]
# Class Probabilities:  [6.09285747e-30 1.85381762e-03 1.31434664e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.11518005 -5.99608685]
# Class Probabilities:  [2.25966319e-02 1.42883856e-12 1.50260815e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.61237327 4.48009751]
# Class Probabilities:  [7.79126528e-10 2.25069032e-12 1.13580651e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.95457177 -2.6426557 ]
# Class Probabilities:  [8.44884328e-04 4.11034423e-07 7.92140894e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.91149048 -9.43001297]
# Class Probabilities:  [5.48148588e-03 3.28802382e-17 3.91983840e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.90520993  5.66899844]
# Class Probabilities:  [5.04174828e-14 2.72182966e-06 7.71611795e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.82381941  9.48699204]
# Class Probabilities:  [1.60302925e-20 1.68752368e-04 2.26370909e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.51481518 -2.69629369]
# Class Probabilities:  [1.08169219e-05 1.48538428e-08 4.08213283e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.81850398 -1.42510573]
# Class Probabilities:  [1.65159006e-06 5.48462328e-09 9.42402691e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.32369809 -7.1393455 ]
# Class Probabilities:  [7.37578728e-03 4.85275342e-12 1.05492670e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.46861438 -1.4433357 ]
# Class Probabilities:  [3.12015410e-04 3.28827308e-09 8.68065985e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.98740359 -5.57716425]
# Class Probabilities:  [6.47809161e-03 9.27284340e-10 4.02372775e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.65009927  4.93480248]
# Class Probabilities:  [2.24964195e-13 1.80719754e-19 9.39717499e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.29799896 -4.9997967 ]
# Class Probabilities:  [1.70698318e-02 7.50354217e-12 2.48978461e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.39210413 -8.94948394]
# Class Probabilities:  [7.30513420e-03 1.24779009e-20 2.88616289e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.03147831 -1.78716335]
# Class Probabilities:  [2.02718041e-03 2.30244024e-06 4.29218262e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.24658383 -0.90643208]
# Class Probabilities:  [4.32461438e-09 4.21781520e-12 9.94049380e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.56004924 -1.02757626]
# Class Probabilities:  [2.57115487e-05 1.74178533e-07 6.86530124e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.36264317 -0.22355351]
# Class Probabilities:  [6.15757281e-09 6.49276220e-12 1.03813221e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.87468243  1.68851414]
# Class Probabilities:  [3.95110235e-06 9.13601661e-06 1.15456741e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.71271544 -9.47990792]
# Class Probabilities:  [3.01403257e-05 1.11291018e-13 3.96719032e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-6.79673036 -6.33979581]
# Class Probabilities:  [1.43590869e-02 4.02548882e-15 3.17852551e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.06008745 9.97311029]
# Class Probabilities:  [1.85259493e-15 1.82050856e-02 2.53240667e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.82746067 -3.56345126]
# Class Probabilities:  [8.45551888e-03 4.26461796e-10 1.57798118e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.90632459 -9.21895769]
# Class Probabilities:  [8.03158056e-03 4.68508424e-20 6.36846304e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.36874346 0.62545597]
# Class Probabilities:  [1.15691766e-08 1.74408355e-11 1.00656318e-02]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.22552188 -0.20662172]
# Class Probabilities:  [4.59203565e-10 1.80248255e-13 7.82177757e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.20850538 -2.82403166]
# Class Probabilities:  [5.75215556e-04 2.55985379e-07 9.10637998e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.21579751 2.94840046]
# Class Probabilities:  [6.36664398e-06 3.18548649e-05 2.43631942e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.20729307 -5.44771275]
# Class Probabilities:  [8.37783548e-03 9.72590801e-10 3.32420578e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.40036386 -5.32174925]
# Class Probabilities:  [1.87294640e-02 2.88997576e-12 1.56713396e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.15531485 -4.12155615]
# Class Probabilities:  [1.31559602e-03 4.02237302e-08 1.66210762e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.22382129 5.71360307]
# Class Probabilities:  [1.01656489e-10 2.17250977e-13 2.75509557e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.63952042 -4.65786291]
# Class Probabilities:  [2.62697939e-03 1.38023357e-08 4.79306541e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.15705042 1.29990602]
# Class Probabilities:  [1.02842816e-10 1.28864868e-14 4.40286956e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.95944226  1.34437573]
# Class Probabilities:  [2.16593857e-13 8.38537091e-19 1.18846599e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [12.70138697  4.8417071 ]
# Class Probabilities:  [6.66609487e-15 1.82059488e-22 3.31891011e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.13412403 8.8823782 ]
# Class Probabilities:  [6.04312988e-12 7.28470036e-11 6.52179082e-06]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.02416693 11.64233379]
# Class Probabilities:  [1.85497264e-21 9.21930733e-03 4.44242870e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.06908312 1.27293507]
# Class Probabilities:  [1.34011816e-04 9.26533893e-05 1.09152797e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 9.66236602 -2.51130178]
# Class Probabilities:  [4.59196644e-14 7.98791257e-18 1.90832206e-03]
# Predicted class is : 3
# ******************************************************************************

# %%
# TODO [8]: Compute the accuracy of the generated Bayesian classifier 
# WITHOUT USING ANY FOR LOOPs.
predicted_classes = np.array(predicted_classes)
accuracy = np.count_nonzero(predicted_classes.reshape(-1) == test_data_true.reshape(-1))/K
print('Accuracy = ' + str(round(accuracy,4) * 100) + '%')
# Out:
# Accuracy = 95.78%

# %%
# TODO [9]: Generate a 3D-plot for the generated distributions. x-axis and y-axis represent the features of the data, 
#           where z-axis represent the Gaussian probability N at this point.

x = np.linspace(-10, 10, 300)
y = np.linspace(-10, 15, 300)
X, Y = np.meshgrid(x, y)
Z = np.zeros(X.shape)

for i in range(Z.shape[0]):
    for j in range(Z.shape[1]):
        # TODO [9]: Fill in the matrix Z which will represent the probability distribution of every point.
        # Z[i,j] represents the joint probability N(x,y) for x = i and y = j. 
        # We want to draw the gaussian probability N(x,y) for all points. 
        Z[i, j] = 0

# Make a 3D plot, do not change code
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', linewidth=0)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()

# %%
# How can you judge your plot is correct?
'''
    Your Answer:
'''
